# %%
data = [
  {
    "batch_in_id": "1410873000139503356",
    "title": "Shipment may be delayed for batch number: B3030375-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the lack of clear payment terms and the high quantity of 12,880 units, which could complicate processing.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22595",
    "sku": 2017,
    "po_comitted": "Direct Sale",
    "probability": [
      0.59,
      0.41
    ]
  },
  {
    "batch_in_id": "1410873000137177231",
    "title": "Shipment may be delayed for batch number: AZ22192-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because there are no payment terms set and the shipping port is Visakhapatnam, which could complicate the process.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22192",
    "sku": 2015,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000137754121",
    "title": "Shipment may be delayed for batch number: AZ22195-India",
    "prediction": "delayed",
    "message": "This shipment may be delayed due to the shipping port of Visakhapatnam and the quantity of 12,880 units, which can lead to processing delays.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22195",
    "sku": 2017,
    "po_comitted": "Direct Sale",
    "probability": [
      0.61,
      0.39
    ]
  },
  {
    "batch_in_id": "1410873000134674123",
    "title": "Shipment may be delayed for batch number: AZ22595-India",
    "prediction": "delayed",
    "message": "This shipment may be delayed likely due to the lack of payment terms and the shipping port being Visakhapatnam, which can affect processing times.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22595",
    "sku": 2017,
    "po_comitted": "Direct Sale",
    "probability": [
      0.59,
      0.41
    ]
  },
  {
    "batch_in_id": "1410873000139670508",
    "title": "Shipment may be delayed for batch number: B3030367-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because it is scheduled to ship from Visakhapatnam, and has a significant quantity of 12,880 units, which could complicate timely processing.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22195",
    "sku": 2017,
    "po_comitted": "Direct Sale",
    "probability": [
      0.61,
      0.39
    ]
  },
  {
    "batch_in_id": "1410873000139457987",
    "title": "Shipment may be delayed for batch number: B3030374-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to factors like the shipping port and brand not contributing positively, indicating potential issues with processing or logistics.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ19775",
    "sku": 2017,
    "po_comitted": "Direct Sale",
    "probability": [
      0.59,
      0.41
    ]
  },
  {
    "batch_in_id": "1410873000139492212",
    "title": "Shipment may be delayed for batch number: B3030361-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the lack of payment terms and the shipping port being Visakhapatnam, which could be affecting processing times.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22192",
    "sku": 2015,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000134664311",
    "title": "Shipment may be delayed for batch number: AZ19775-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because there are no significant issues with payment terms, shipping port, SCAC, brand, or quantity, which suggests that factors outside these features are likely causing the delay.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ19775",
    "sku": 2017,
    "po_comitted": "Direct Sale",
    "probability": [
      0.59,
      0.41
    ]
  },
  {
    "batch_in_id": "1410873000136979738",
    "title": "Shipment may be delayed for batch number: AZ22194-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because the payment terms and shipping port have no positive influence on speeding up the process, suggesting potential administrative issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22194",
    "sku": 2015,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000139457407",
    "title": "Shipment may be delayed for batch number: B3030362-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because of the scheduled shipping from Visakhapatnam and the large quantity of 30,720 units, which can complicate logistics.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22194",
    "sku": 2015,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000136738094",
    "title": "Shipment may be delayed for batch number: B3029590-Ecuador",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the high quantity of 35,000 units, which can complicate logistics and lead to potential delays.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000068575487",
    "customer_po": "AZ22030",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.8,
      0.2
    ]
  },
  {
    "batch_in_id": "1410873000139461741",
    "title": "Shipment may be delayed for batch number: AZ22310-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because there are no specific factors like payment terms or shipping port that indicate a smooth process, leading to uncertainty in delivery.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22310",
    "sku": 857,
    "po_comitted": "Direct Sale",
    "probability": [
      0.51,
      0.49
    ]
  },
  {
    "batch_in_id": "1410873000139920648",
    "title": "Shipment may be delayed for batch number: B3030481-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the lack of payment terms and the shipping port being Ennore, which could affect processing times.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207997",
    "customer_po": "AZ21465",
    "sku": 874,
    "po_comitted": "Direct Sale",
    "probability": [
      0.67,
      0.33
    ]
  },
  {
    "batch_in_id": "1410873000139965038",
    "title": "Shipment may be delayed for batch number: AZ22268-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to factors like the shipping port and brand not contributing positively, indicating potential issues in logistics or processing.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22268",
    "sku": 864,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000136981205",
    "title": "Shipment may be delayed for batch number: AZ22268-India",
    "prediction": "delayed",
    "message": "This shipment may be delayed likely due to the long estimated travel duration and the gap between the ETA and the due date, which suggest potential logistical issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22268",
    "sku": 864,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000136981205",
    "title": "Shipment may be delayed for batch number: AZ22268-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because there are no significant factors like payment terms, shipping port, or the brand influencing a timely delivery.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22268",
    "sku": 864,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000139965038",
    "title": "Shipment may be delayed for batch number: AZ22268-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because, despite having no payment terms or issues with the shipping port and brand, the large quantity of goods (35,280 units) could be causing processing delays.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22268",
    "sku": 864,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000139965316",
    "title": "Shipment may be delayed for batch number: AZ23171-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because it has a long estimated travel duration of 53 days, and there's a gap of 14 days between the ETA and the due date.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207997",
    "customer_po": "AZ23171",
    "sku": 869,
    "po_comitted": "Direct Sale",
    "probability": [
      0.64,
      0.36
    ]
  },
  {
    "batch_in_id": "1410873000139772687",
    "title": "Shipment may be delayed for batch number: AZ21664-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the shipping port and SCAC not contributing positively, indicating potential operational issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207997",
    "customer_po": "AZ21664",
    "sku": 874,
    "po_comitted": "Direct Sale",
    "probability": [
      0.66,
      0.34
    ]
  },
  {
    "batch_in_id": "1410873000139605170",
    "title": "Shipment may be delayed for batch number: B3030376-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the payment terms and shipping port not contributing positively to the delivery timeline.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22189",
    "sku": 2013,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000136374536",
    "title": "Shipment may be delayed for batch number: AZ22185-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the lack of specific factors like payment terms and shipping port details, which did not contribute positively to the prediction.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22185",
    "sku": 2013,
    "po_comitted": "Direct Sale",
    "probability": [
      0.53,
      0.47
    ]
  },
  {
    "batch_in_id": "1410873000139670399",
    "title": "Shipment may be delayed for batch number: B3030388-India",
    "prediction": "delayed",
    "message": "This shipment may be delayed because, despite having a large quantity of 17,200 units, the shipping port and other factors did not contribute positively to timely processing.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22184",
    "sku": 2013,
    "po_comitted": "Direct Sale",
    "probability": [
      0.61,
      0.39
    ]
  },
  {
    "batch_in_id": "1410873000135408502",
    "title": "Shipment may be delayed for batch number: AZ22016-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because there is no payment made yet and the shipping port might be causing logistical issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22016",
    "sku": 897,
    "po_comitted": "Direct Sale",
    "probability": [
      0.63,
      0.37
    ]
  },
  {
    "batch_in_id": "1410873000135220558",
    "title": "Shipment may be delayed for batch number: AZ22183-India",
    "prediction": "delayed",
    "message": "This shipment may be delayed due to the lack of payment terms and the shipping port being Visakhapatnam, which could contribute to processing issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22183",
    "sku": 2013,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000137177258",
    "title": "Shipment may be delayed for batch number: AZ22189-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because the payment terms are not set, which can complicate processing and shipping arrangements.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22189",
    "sku": 2013,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000139683688",
    "title": "Shipment may be delayed for batch number: B3030387-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because it has a significant quantity of 33,750 units, which can complicate logistics and slow down processing at the shipping port.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000018004764",
    "customer_po": "AZ22160",
    "sku": 856,
    "po_comitted": "Direct Sale",
    "probability": [
      0.5,
      0.5
    ]
  },
  {
    "batch_in_id": "1410873000138308886",
    "title": "Shipment may be delayed for batch number: AZ22593-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the combination of factors like the shipping port and brand not contributing positively, indicating potential issues at the Visakhapatnam port or with the GREAT VALUE brand.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22593",
    "sku": 2017,
    "po_comitted": "Direct Sale",
    "probability": [
      0.61,
      0.39
    ]
  },
  {
    "batch_in_id": "1410873000139683776",
    "title": "Shipment may be delayed for batch number: B3030377-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because key features like the shipping port and brand did not contribute positively to timely delivery, indicating potential logistical issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22183",
    "sku": 2013,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000134601937",
    "title": "Shipment may be delayed for batch number: AZ22593-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the scheduling complexities associated with the shipping port and the brand, which did not contribute positively to timely delivery.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22593",
    "sku": 2017,
    "po_comitted": "Direct Sale",
    "probability": [
      0.61,
      0.39
    ]
  },
  {
    "batch_in_id": "1410873000139776184",
    "title": "Shipment may be delayed for batch number: AZ22287-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the estimated travel duration and the gap between the ETA and due date, which suggests potential scheduling issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22287",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.63,
      0.37
    ]
  },
  {
    "batch_in_id": "1410873000137754467",
    "title": "Shipment may be delayed for batch number: AZ22184-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because all contributing features, such as payment terms, shipping port, and quantity, did not indicate any urgency, leading to a higher likelihood of delay.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22184",
    "sku": 2013,
    "po_comitted": "Direct Sale",
    "probability": [
      0.61,
      0.39
    ]
  },
  {
    "batch_in_id": "1410873000139492104",
    "title": "Shipment may be delayed for batch number: B3030309-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the shipping port and brand not contributing positively to the delivery schedule, indicating potential issues in those areas.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22593",
    "sku": 2017,
    "po_comitted": "Direct Sale",
    "probability": [
      0.61,
      0.39
    ]
  },
  {
    "batch_in_id": "1410873000136982921",
    "title": "Shipment may be delayed for batch number: AZ22287-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because there are no influencing factors from payment terms, shipping port, or brand that could expedite the process.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22287",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.63,
      0.37
    ]
  },
  {
    "batch_in_id": "1410873000139492890",
    "title": "Shipment may be delayed for batch number: B3030364-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the long estimated travel duration of 46 days and the gap until the due date, which is 17 days.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22016",
    "sku": 897,
    "po_comitted": "Direct Sale",
    "probability": [
      0.63,
      0.37
    ]
  },
  {
    "batch_in_id": "1410873000139844781",
    "title": "Shipment may be delayed for batch number: B3030498-India",
    "prediction": "delayed",
    "message": "This shipment may be delayed due to the lack of payment terms and the shipping port being Visakhapatnam, which could affect processing times.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22185",
    "sku": 2013,
    "po_comitted": "Direct Sale",
    "probability": [
      0.53,
      0.47
    ]
  },
  {
    "batch_in_id": "1410873000139839807",
    "title": "Shipment may be delayed for batch number: AZ20551-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because the payment terms and shipping port did not negatively impact the prediction, suggesting potential issues with processing or logistics despite the expected travel duration.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ20551",
    "sku": 2013,
    "po_comitted": "Direct Sale",
    "probability": [
      0.52,
      0.48
    ]
  },
  {
    "batch_in_id": "1410873000137488131",
    "title": "Shipment may be delayed for batch number: B3029617-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the lengthy payment terms and the estimated travel duration being close to the due date.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000201701",
    "customer_po": "AZ21486",
    "sku": 2017,
    "po_comitted": "Direct Sale",
    "probability": [
      0.97,
      0.03
    ]
  },
  {
    "batch_in_id": "1410873000140243186",
    "title": "Shipment may be delayed for batch number: B3030656-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the long estimated travel duration combined with the due date that is significantly later than the estimated time of arrival.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000895203",
    "customer_po": "AZ22047",
    "sku": 858,
    "po_comitted": "Direct Sale",
    "probability": [
      0.5,
      0.5
    ]
  },
  {
    "batch_in_id": "1410873000140433046",
    "title": "Shipment may be delayed for batch number: B3030667-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed likely due to the shipping port and brand not contributing positively, indicating potential logistical issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22282",
    "sku": 870,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000139456266",
    "title": "Shipment may be delayed for batch number: AZ22299-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because it has a large quantity of 35,000 units and is shipped from Visakhapatnam, which could lead to longer processing times.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22299",
    "sku": 874,
    "po_comitted": "Direct Sale",
    "probability": [
      0.69,
      0.31
    ]
  },
  {
    "batch_in_id": "1410873000140208017",
    "title": "Shipment may be delayed for batch number: AZ23026-Ecuador",
    "prediction": "delayed",
    "message": "The shipment may be delayed because it is scheduled to leave from Guayaquil, and despite the large quantity of 35,000 units, there are no payment terms or specific shipping details that indicate a smooth process.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000068575487",
    "customer_po": "AZ23026",
    "sku": 855,
    "po_comitted": "Direct Sale",
    "probability": [
      0.51,
      0.49
    ]
  },
  {
    "batch_in_id": "1410873000140413547",
    "title": "Shipment may be delayed for batch number: B3030668-Indonesia",
    "prediction": "delayed",
    "message": "This shipment may be delayed because the estimated travel duration and other factors, like shipping port and payment terms, did not contribute positively to timely delivery.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000078384657",
    "customer_po": "AZ20315",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000137144796",
    "title": "Shipment may be delayed for batch number: AZ20315-Indonesia",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the estimated travel duration and the gap between the eta and due date not being sufficient to meet the timeline.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000078384657",
    "customer_po": "AZ20315",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000140095073",
    "title": "Shipment may be delayed for batch number: AZ22041-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the estimated travel duration being long, which could lead to a gap between the ETA and the due date.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207997",
    "customer_po": "AZ22041",
    "sku": 874,
    "po_comitted": "Direct Sale",
    "probability": [
      0.68,
      0.32
    ]
  },
  {
    "batch_in_id": "1410873000139272542",
    "title": "Shipment may be delayed for batch number: AZ22267-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because it has a long estimated travel duration, and no significant factors like payment terms or shipping port are contributing positively to expedite the process.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22267",
    "sku": 864,
    "po_comitted": "Direct Sale",
    "probability": [
      0.64,
      0.36
    ]
  },
  {
    "batch_in_id": "1410873000139272542",
    "title": "Shipment may be delayed for batch number: AZ22267-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because key factors like the shipping port and brand did not contribute positively to the prediction, indicating potential issues with logistics or processing.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22267",
    "sku": 864,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000138564456",
    "title": "Shipment may be delayed for batch number: AZ22267-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the long estimated travel duration and the gap between the ETA and due date.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22267",
    "sku": 864,
    "po_comitted": "Direct Sale",
    "probability": [
      0.64,
      0.36
    ]
  },
  {
    "batch_in_id": "1410873000138564456",
    "title": "Shipment may be delayed for batch number: AZ22267-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the lack of specific factors like payment terms and shipping port conditions, which typically help ensure timely delivery.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22267",
    "sku": 864,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000135681729",
    "title": "Shipment may be delayed for batch number: AZ22313-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the lack of payment terms, which could impact processing, despite the shipping port and other features showing no issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22313",
    "sku": 857,
    "po_comitted": "Direct Sale",
    "probability": [
      0.5,
      0.5
    ]
  },
  {
    "batch_in_id": "1410873000137711945",
    "title": "Shipment may be delayed for batch number: AZ21663-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the long estimated travel duration and the substantial quantity of 35,200 units being shipped.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207997",
    "customer_po": "AZ21663",
    "sku": 874,
    "po_comitted": "Direct Sale",
    "probability": [
      0.68,
      0.32
    ]
  },
  {
    "batch_in_id": "1410873000137711945",
    "title": "Shipment may be delayed for batch number: AZ21663-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because it has a long estimated travel duration and is scheduled to arrive after the due date.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207997",
    "customer_po": "AZ21663",
    "sku": 874,
    "po_comitted": "Direct Sale",
    "probability": [
      0.74,
      0.26
    ]
  },
  {
    "batch_in_id": "1410873000138642148",
    "title": "Shipment may be delayed for batch number: AZ22803-Indonesia",
    "prediction": "delayed",
    "message": "The shipment may be delayed because it has an unknown shipping port and lacks a clear receipt date, which can complicate logistics.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000078384657",
    "customer_po": "AZ22803",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.64,
      0.36
    ]
  },
  {
    "batch_in_id": "1410873000138642148",
    "title": "Shipment may be delayed for batch number: AZ22803-Indonesia",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the current estimated travel duration and the lack of payment terms, which could affect processing times.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000078384657",
    "customer_po": "AZ22803",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000140571009",
    "title": "Shipment may be delayed for batch number: AZ22803-Indonesia",
    "prediction": "delayed",
    "message": "The shipment may be delayed because there are no significant factors like payment terms, shipping port, or quantity that would expedite the process.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000078384657",
    "customer_po": "AZ22803",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000140571009",
    "title": "Shipment may be delayed for batch number: AZ22803-Indonesia",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the unknown shipping port, which can complicate logistics and lead to delays.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000078384657",
    "customer_po": "AZ22803",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.64,
      0.36
    ]
  },
  {
    "batch_in_id": "1410873000139193931",
    "title": "Shipment may be delayed for batch number: B3029417-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the long estimated travel duration and the payment terms, which could be affecting the overall processing time.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000201701",
    "customer_po": "AZ22191",
    "sku": 2015,
    "po_comitted": "Direct Sale",
    "probability": [
      0.81,
      0.19
    ]
  },
  {
    "batch_in_id": "1410873000140318853",
    "title": "Shipment may be delayed for batch number: AZ22259-India",
    "prediction": "delayed",
    "message": "This shipment may be delayed because it has a large quantity of 33,600 units and is still pending payment terms, which could impact its timely processing.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22259",
    "sku": 1350,
    "po_comitted": "Direct Sale",
    "probability": [
      0.58,
      0.42
    ]
  },
  {
    "batch_in_id": "1410873000139217673",
    "title": "Shipment may be delayed for batch number: B3028450-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the long estimated travel duration of 73 days, which exceeds the expected arrival time.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ20812",
    "sku": 870,
    "po_comitted": "Direct Sale",
    "probability": [
      0.79,
      0.21
    ]
  },
  {
    "batch_in_id": "1410873000140848666",
    "title": "Shipment may be delayed for batch number: AZ22254-Vietnam",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the long estimated travel duration of 40 days and a gap of 8 days between the ETA and due date, indicating potential scheduling issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206609",
    "customer_po": "AZ22254",
    "sku": 871,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000139077371",
    "title": "Shipment may be delayed for batch number: B3030219-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because there are no specific issues identified with payment terms, shipping port, SCAC, brand, or quantity, indicating that other factors not captured here could be causing the delay.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ21108",
    "sku": 870,
    "po_comitted": "Direct Sale",
    "probability": [
      0.62,
      0.38
    ]
  },
  {
    "batch_in_id": "1410873000137753665",
    "title": "Shipment may be delayed for batch number: AZ22802-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the long estimated travel duration of 66 days and the gap between the estimated arrival and due date.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207997",
    "customer_po": "AZ22802",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.66,
      0.34
    ]
  },
  {
    "batch_in_id": "1410873000139684956",
    "title": "Shipment may be delayed for batch number: AZ22802-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to the lack of payment terms and the shipping port, which could indicate processing issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207997",
    "customer_po": "AZ22802",
    "sku": 865,
    "po_comitted": "Direct Sale",
    "probability": [
      0.66,
      0.34
    ]
  },
  {
    "batch_in_id": "1410873000137182163",
    "title": "Shipment may be delayed for batch number: AZ21667-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed because it is scheduled to ship from Visakhapatnam, and the large quantity of 33,750 units could complicate logistics.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ21667",
    "sku": 856,
    "po_comitted": "Direct Sale",
    "probability": [
      0.51,
      0.49
    ]
  },
  {
    "batch_in_id": "1410873000137181325",
    "title": "Shipment may be delayed for batch number: AZ22303-India",
    "prediction": "delayed",
    "message": "This shipment may be delayed due to the estimated travel duration being longer than expected, despite factors like payment terms and shipping port showing no immediate issues.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22303",
    "sku": 1937,
    "po_comitted": "Direct Sale",
    "probability": [
      0.69,
      0.31
    ]
  },
  {
    "batch_in_id": "1410873000137796633",
    "title": "Shipment may be delayed for batch number: AZ22283-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed due to factors like the shipping port and brand, which haven't shown any positive contributions towards timely delivery.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000206411",
    "customer_po": "AZ22283",
    "sku": 870,
    "po_comitted": "Direct Sale",
    "probability": [
      0.7,
      0.3
    ]
  },
  {
    "batch_in_id": "1410873000137192295",
    "title": "Shipment may be delayed for batch number: AZ22298-India",
    "prediction": "delayed",
    "message": "The shipment may be delayed likely due to the estimated travel duration being long, as indicated by the high quantity of 35,000 units, which can slow down processing.",
    "customer_name": "Walmart",
    "vendor_id": "1410873000000207967",
    "customer_po": "AZ22298",
    "sku": 874,
    "po_comitted": "Direct Sale",
    "probability": [
      0.73,
      0.27
    ]
  }
]

# %%
messages = []

# %%
for i in data:
    messages.append({"batch_id":i['batch_in_id'],
     "messages": i['message']})

# %%
messages
# Out:
# [{'batch_id': '1410873000139503356',
#   'messages': 'The shipment may be delayed due to the lack of clear payment terms and the high quantity of 12,880 units, which could complicate processing.'},
#  {'batch_id': '1410873000137177231',
#   'messages': 'The shipment may be delayed because there are no payment terms set and the shipping port is Visakhapatnam, which could complicate the process.'},
#  {'batch_id': '1410873000137754121',
#   'messages': 'This shipment may be delayed due to the shipping port of Visakhapatnam and the quantity of 12,880 units, which can lead to processing delays.'},
#  {'batch_id': '1410873000134674123',
#   'messages': 'This shipment may be delayed likely due to the lack of payment terms and the shipping port being Visakhapatnam, which can affect processing times.'},
#  {'batch_id': '1410873000139670508',
# ...
