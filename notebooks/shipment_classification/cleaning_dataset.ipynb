# %%
import pandas as pd

# %%
df = pd.read_csv('./results/raw_shipment_classification_dataset.csv')

# %%
df.duplicated().sum()
# Out:
# np.int64(253)

# %%
df.columns
# Out:
# Index(['quantity_in', 'bill_date', 'shipped_date', 'due_date', 'eta', 'seal',
#        'customs_broker', 'receipt_date', 'gross_weight_lb', 'ocean_freight',
#        'yield_percentage', 'shipment_delay_days', 'shipment_classified'],
#       dtype='object')

# %%
# rounding off 
# df['discount'] = df['discount'].apply(lambda x: round(x, 2))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2043 entries, 0 to 2042
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   quantity_in          2043 non-null   float64
#  1   bill_date            2043 non-null   object
#  2   shipped_date         1614 non-null   object
#  3   due_date             2043 non-null   object
#  4   eta                  2043 non-null   object
#  5   seal                 2043 non-null   object
#  6   customs_broker       2037 non-null   object
#  7   receipt_date         2043 non-null   object
#  8   gross_weight_lb      568 non-null    float64
#  9   ocean_freight        432 non-null    float64
#  10  yield_percentage     1581 non-null   object
#  11  shipment_delay_days  2043 non-null   int64
#  12  shipment_classified  2043 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 207.6+ KB

# %%
# df['payment_terms'] = df['payment_terms'].apply(lambda x: abs(x))

# %%
# df['vessel__voyage'] = df['vessel__voyage'].replace(['-', "'-", "'- "], 'unknown')

# %%
# df['container'] = df['container'].replace(['-', "'-", "'- "], 'unknown')

# %%
# df['fda_status'] = df['fda_status'].replace(['-', "'-", "'- "], 'unknown')

# %%
# df['coo'] = df['coo'].replace(['-', "'-", "'- ","'-"], 'unknown')

# %%
df['seal'] = df['seal'].replace(['-', "'-", "'- ","'-"], 'unknown')

# %%
# df['shipment_terms'] = df['shipment_terms'].replace(['-', "'-", "'- ","'-"], 'unknown')

# %%
empty_counts = (df == '').sum()

empty_counts = empty_counts[empty_counts > 0]

print(empty_counts)
# Out:
# Series([], dtype: int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2043 entries, 0 to 2042
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   quantity_in          2043 non-null   float64
#  1   bill_date            2043 non-null   object
#  2   shipped_date         1614 non-null   object
#  3   due_date             2043 non-null   object
#  4   eta                  2043 non-null   object
#  5   seal                 2043 non-null   object
#  6   customs_broker       2037 non-null   object
#  7   receipt_date         2043 non-null   object
#  8   gross_weight_lb      568 non-null    float64
#  9   ocean_freight        432 non-null    float64
#  10  yield_percentage     1581 non-null   object
#  11  shipment_delay_days  2043 non-null   int64
#  12  shipment_classified  2043 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 207.6+ KB

# %%
df.isna().sum()
# Out:
# quantity_in               0
# bill_date                 0
# shipped_date            429
# due_date                  0
# eta                       0
# seal                      0
# customs_broker            6
# receipt_date              0
# gross_weight_lb        1475
# ocean_freight          1611
# yield_percentage        462
# shipment_delay_days       0
# shipment_classified       0
# dtype: int64

# %%
df['customs_broker'].fillna('unknown', inplace=True) # imputing with the new category 'unknown'
# Out:
# /var/folders/m7/x79pvj7n0mxdf4v8ky2kds6h0000gn/T/ipykernel_85929/2693951199.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['customs_broker'].fillna('unknown', inplace=True) # imputing with the new category 'unknown'

# %%
# df['port_of_discharge'].fillna('unknown', inplace=True) # imputing with the new category 'unknown'

# %%
# df.dropna(inplace=True)

# %%
# df['vendor_id']

# %%
# import unicodedata
# import re

# def clean_quotes(x):
#     if not isinstance(x, str):
#         return x
#     x = unicodedata.normalize('NFKD', x)
#     x = re.sub(r'["“”‟‟‟′″‶‷❝❞❮❯❰❱❴❵‘’‚‛‹›]', '', x)
#     return x.strip()

# df['shipment_terms'] = df['shipment_terms'].apply(clean_quotes)

# %%
# df['vessel__voyage'] = df['vessel__voyage'].apply(
#     lambda x: x.strip() if isinstance(x, str) else x
# )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2043 entries, 0 to 2042
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   quantity_in          2043 non-null   float64
#  1   bill_date            2043 non-null   object
#  2   shipped_date         1614 non-null   object
#  3   due_date             2043 non-null   object
#  4   eta                  2043 non-null   object
#  5   seal                 2043 non-null   object
#  6   customs_broker       2043 non-null   object
#  7   receipt_date         2043 non-null   object
#  8   gross_weight_lb      568 non-null    float64
#  9   ocean_freight        432 non-null    float64
#  10  yield_percentage     1581 non-null   object
#  11  shipment_delay_days  2043 non-null   int64
#  12  shipment_classified  2043 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 207.6+ KB

# %%
df[df.duplicated()]
# Out:
#       quantity_in   bill_date shipped_date    due_date         eta  \
# 1         29892.0  2025-10-15   2025-08-23  2025-11-14  2025-10-11
# 2         29892.0  2025-10-15   2025-08-23  2025-11-14  2025-10-11
# 3         29892.0  2025-10-15   2025-08-23  2025-11-14  2025-10-11
# 5          4452.0  2025-10-15   2025-08-23  2025-11-14  2025-10-11
# 6          4452.0  2025-10-15   2025-08-23  2025-11-14  2025-10-11
# ...           ...         ...          ...         ...         ...
# 960        4608.0  2024-01-31   2023-11-26  2024-05-30  2024-01-29
# 989        1800.0  2024-01-31   2023-11-26  2024-05-30  2024-01-29
# 991       18592.0  2024-01-31   2023-11-26  2024-05-30  2024-01-29
# 1037         20.0  2023-07-28   2023-06-14  2023-10-11  2023-07-23
# 1078      35000.0  2023-07-28   2023-06-14  2023-10-11  2023-07-23
#
#               seal         customs_broker receipt_date  gross_weight_lb  \
# 1     ML‐VN1070549  Western Overseas Corp   2025-10-15         46951.93
# 2     ML‐VN1070549  Western Overseas Corp   2025-10-15         46951.93
# 3     ML‐VN1070549  Western Overseas Corp   2025-10-15         46951.93
# 5     ML‐VN1070549  Western Overseas Corp   2025-10-15         46951.93
# 6     ML‐VN1070549  Western Overseas Corp   2025-10-15         46951.93
# ...            ...                    ...          ...              ...
# 960       C6065058      Rod International   2024-01-31              NaN
# 989       C6065058      Rod International   2024-01-31              NaN
# 991       C6065058      Rod International   2024-01-31              NaN
# 1037    HLG6144330      Rod International   2023-07-28              NaN
# 1078    HLG6144330      Rod International   2023-07-28              NaN
#
#       ocean_freight yield_percentage  shipment_delay_days shipment_classified
# 1            3520.0              NaN                    4             on_time
# 2            3520.0              NaN                    4             on_time
# 3            3520.0              NaN                    4             on_time
# 5            3520.0              NaN                    4             on_time
# 6            3520.0              NaN                    4             on_time
# ...             ...              ...                  ...                 ...
# 960             NaN              82%                    2             on_time
# 989             NaN              82%                    2             on_time
# 991             NaN              82%                    2             on_time
# 1037            NaN              NaN                    5             on_time
# 1078            NaN              NaN                    5             on_time
#
# [253 rows x 13 columns]

# %%
import pandas as pd
import re

def clean_currency_column(series: pd.Series) -> pd.Series:
    return (
        series.astype(str)
        .str.replace(r'[\"\']', '', regex=True)                 # remove quotes
        .str.replace(r'\s*USD\s*', '', regex=True, case=False)  # remove USD
        .str.replace(',', '', regex=True)                       # remove commas
        .str.replace(r'\(', '-', regex=True)                    # handle (negatives)
        .str.replace(r'\)', '', regex=True)                     # remove )
        .str.replace(r'[^0-9\.-]', '', regex=True)              # keep only numbers, dot, minus
        .replace('', '0')
        .astype(float)
        .abs()                                                  # convert to absolute
    )

# Apply to your columns
# df['bill_item_quantity'] = clean_currency_column(df['bill_item_quantity'])
# df['bill_item_price_bcy'] = clean_currency_column(df['bill_item_price_bcy'])
# df['bill_item_total_bcy'] = clean_currency_column(df['bill_item_total_bcy'])
# df['ocean_freight'] = clean_currency_column(df['ocean_freight'])
# df['purchase_price'] = clean_currency_column(df['purchase_price'])
# df['sales_price'] = clean_currency_column(df['sales_price'])

# %%
def fill_unknown_for_object_cols(df: pd.DataFrame) -> pd.DataFrame:
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].replace(r'^\s*$', 'unknown', regex=True)
    return df

df = fill_unknown_for_object_cols(df)

# %%
# df['bill_item_size'].fillna('unknown', inplace=True)

# %%
df['gross_weight_lb'].isna().sum()
# Out:
# np.int64(1475)

# %%
df.columns
# Out:
# Index(['quantity_in', 'bill_date', 'shipped_date', 'due_date', 'eta', 'seal',
#        'customs_broker', 'receipt_date', 'gross_weight_lb', 'ocean_freight',
#        'yield_percentage', 'shipment_delay_days', 'shipment_classified'],
#       dtype='object')

# %%
# df['tariff_type'].fillna('unknown', inplace=True)
# df['consignee'].fillna('unknown', inplace=True)
# df['item_size'].fillna('unknown', inplace=True)
# df['item_type'].fillna('unknown', inplace=True)
# df['bill_item_cases'].fillna(0, inplace=True)
# df['bill_item_quantity'].fillna(0, inplace=True)
# df['bill_item_cs_weight'].fillna(0, inplace=True)
# df['bill_type'].fillna('unknown', inplace=True)
# df['seal'].fillna('unknown', inplace=True)
# df['brand'].fillna('unknown', inplace=True)
# df['manufacturer'].fillna('unknown', inplace=True)
df['receipt_date'].fillna('unknown', inplace=True)
# Out:
# /var/folders/m7/x79pvj7n0mxdf4v8ky2kds6h0000gn/T/ipykernel_85929/2482146571.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['receipt_date'].fillna('unknown', inplace=True)

# %%
# columns to drop due to high missing values
columns_to_drop = ['gross_weight_lb','tariff_amount','place_of_delivery','shipping_port','cooking_style','transshipment_date_ett',
                    'product_type','product_category','shipment_delay_days', 
                    'sales_account', 'sales_price', 'ocean_freight']
columns_to_drop_due_to_single_value = ['purchase_price','opening_stock', 'item_cases']
columns_to_drop_due_to_no_relation_with_target = ['consignee','fda_status', 'status','bill_type' ,'coo', 'item_type', 'manufacturer', 'soaking_style', 'item_size','bill_status','inventory','tariff_type','brand']

# Combine all columns to drop
all_columns_to_drop = (
    columns_to_drop +
    columns_to_drop_due_to_single_value +
    columns_to_drop_due_to_no_relation_with_target
)

# Keep only columns that exist in df
cols_to_drop_existing = [col for col in all_columns_to_drop if col in df.columns]

# Drop them
df.drop(columns=cols_to_drop_existing, inplace=True)

# %%
df.columns
# Out:
# Index(['quantity_in', 'bill_date', 'shipped_date', 'due_date', 'eta', 'seal',
#        'customs_broker', 'receipt_date', 'yield_percentage',
#        'shipment_classified'],
#       dtype='object')

# %%
# df['soaking_style'].fillna('unknown', inplace=True)
df['yield_percentage'] = (
    df['yield_percentage']
    .astype(str)
    .str.replace('%', '', regex=False)
    .astype(float)
)
df['yield_percentage'].fillna(0, inplace=True)
# Out:
# /var/folders/m7/x79pvj7n0mxdf4v8ky2kds6h0000gn/T/ipykernel_85929/2405809000.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['yield_percentage'].fillna(0, inplace=True)

# %%
df['shipped_date'].fillna(df['bill_date'], inplace=True)

# %%
df.isna().sum()
# Out:
# quantity_in            0
# bill_date              0
# shipped_date           0
# due_date               0
# eta                    0
# seal                   0
# customs_broker         0
# receipt_date           0
# yield_percentage       0
# shipment_classified    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1790 entries, 0 to 2042
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   quantity_in          1790 non-null   float64
#  1   bill_date            1790 non-null   object
#  2   shipped_date         1790 non-null   object
#  3   due_date             1790 non-null   object
#  4   eta                  1790 non-null   object
#  5   seal                 1790 non-null   object
#  6   customs_broker       1790 non-null   object
#  7   receipt_date         1790 non-null   object
#  8   yield_percentage     1790 non-null   float64
#  9   shipment_classified  1790 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 153.8+ KB

# %%
df['seal'].replace(['UNKNOWN', ''], 'unknown', inplace=True)
# Out:
# /var/folders/m7/x79pvj7n0mxdf4v8ky2kds6h0000gn/T/ipykernel_85929/3201566763.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['seal'].replace(['UNKNOWN', ''], 'unknown', inplace=True)

# %%
# df['sales_account'] = df['sales_account'].astype(str)
df.drop_duplicates(inplace=True)

# %%
df.drop(columns=['receipt_date'], inplace=True)

# %%
df.to_csv('./results/cleaned_shipment_classification_dataset.csv', index=False)
